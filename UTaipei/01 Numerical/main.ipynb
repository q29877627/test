# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# This is a custom matplotlib style that I use for most of my charts
#plt.style.use('https://gist.githubusercontent.com/rhiever/d0a7332fe0beebfdc3d5/raw/205e477cf231330fe2f265070f7c37982fd3130c/tableau10.mplstyle')

age_gender_data = pd.read_csv('applestore0to5.csv')
age_gender_data.head(24)
# Out:
#              NAME  COUNT  hate  favorite
# 0            Book     53    47         6
# 1        Business      6     4         2
# 2        Catalogs      6     5         1
# 3       Education     71    66         5
# 4   Entertainment     78    64        14
# 5         Finance     36    33         3
# 6            Food     13    11         2
# 7           Games    612   462       150
# 8          Health     33    21        12
# 9       Lifestyle     35    31         4
# 10        Medical      5     3         2
# 11          Music      4     4         0
# 12     Navigation     15    15         0
# 13           News     16    15         1
# 14          Photo     45    24        21
# 15    prime_genre      2     1         1
# 16   Productivity     10     6         4
# 17      Reference     11    11         0
# 18       Shopping     28    16        12
# 19         Social     37    33         4
# 20         Sports     14    13         1
# 21         Travel     14    10         4
# 22      Utilities     36    29         7
# 23        Weather      6     6         0

# %%
age_gender_data['hate'] = age_gender_data['hate'] / age_gender_data['COUNT']
age_gender_data['favorite'] = age_gender_data['favorite'] / age_gender_data['COUNT']

plt.figure(figsize=(15, 7))

for (i, row) in age_gender_data.iterrows():
    plt.bar([i], [row['hate']],
            color=['#008AB8'], width=0.9, align='center', edgecolor='none')
    plt.bar([i], [row['favorite']], bottom=[row['hate']],
            color=['#CC6699'], width=0.9, align='center', edgecolor='none')
    
plt.xlim(-0.6, 20.6)
plt.ylim(0, 1)
plt.xticks(range(0, 25), age_gender_data['NAME'], fontsize=11, rotation=45)
plt.grid(False)
plt.yticks(np.arange(0, 1.01, 0.25),
           ['{}%'.format(int(x * 100)) for x in np.arange(0, 1.01, 0.25)])
plt.xlabel('NAME group')
plt.ylabel('Percentage of age group')

plt.plot([-0.425, 23.425], [0.5, 0.5], lw=2, color='black')
plt.plot([-0.425, 23.425], [0.25, 0.25], lw=2, color='black')

plt.savefig('pop_pyramid_stacked.pdf')
;
# Out:
# ''
